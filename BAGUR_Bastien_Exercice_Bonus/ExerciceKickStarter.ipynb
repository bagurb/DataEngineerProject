# %% [markdown]
# #  Consignes
#
# ## Description
#
# Ouvrir le fichier ks-projects-201801.csv, il recense environ 100 000 projets KickStarter. Intégrer les données directement avec L'API Python dans une base de données Mongo.
#
# Il conviendra de bien spécifier manuellement l'ID du document. Pensez aussi à bien formatter le type des données pour profiter des méthodes implémentées par Mongo. L'ensemble de données n'est pas forcément nécessaire, c'est à vous de créer votre modèle de données.
#
# ## Questions
#
# - 1) Récupérer les 5 projets ayant reçu le plus de promesse de dons.
# - 2) Compter le nombre de projets ayant atteint leur but.
# - 3) Compter le nombre de projets pour chaque catégorie.
# - 4) Compter le nombre de projets français ayant été instanciés avant 2016.
# - 5) Récupérer les projets américains ayant demandé plus de 200 000 dollars.
# - 6) Compter le nombre de projet ayant "Sport" dans leur nom

# %%
import pandas as pd
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")
database = client['exercices']
collection = database['kickstarter']

# %%
df_ks = pd.read_csv("./data/ks-projects-201801-sample.csv")
df_ks.head()
# Out:
# C:\Users\basti\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (6,8,10,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            ID                                               name  \
# 0   872782264    Scott Cooper's Solo CD "A Leg Trick" (Canceled)
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category currency    deadline   goal  \
# 0            Rock         Music      USD  2011-09-16   2000
# 1         Fashion       Fashion      USD  2012-08-22  18000
# 2  Tabletop Games         Games      USD  2016-07-19   2000
# 3       Art Books    Publishing      USD  2017-09-27  13000
# 4       Sculpture           Art      CAD  2016-02-24   5000
#
#               launched pledged       state backers country usd pledged  \
# 0  2011-08-17 06:31:31    1145    canceled      24      US        1145
# 1  2012-07-23 20:46:48    1851      failed      28      US        1851
# 2  2016-07-01 21:55:54    7534  successful     254      US        3796
# 3  2017-08-28 15:47:02   16298  successful     367      US        2670
# 4  2016-01-25 17:37:10       1      failed       1      CA    0.708148
#
#    usd_pledged_real
# 0       1145.000000
# 1       1851.000000
# 2       7534.000000
# 3      16298.000000
# 4          0.738225

# %% [markdown]
# Ce warning intervient lorsque pandas n'arrive pas à inférer le type de données. Il est sympa il précise les colones 6,8,10,12.

# %%
df_ks.columns[[6,8,10,12]]
# Out:
# Index(['goal', 'pledged', 'backers', 'usd pledged'], dtype='object')

# %% [markdown]
# ## Question 0

# %% [markdown]
# ### Netoyer les données

# %%
#Tri et Netoyage de la base
df_ks = df_ks.drop(["currency","deadline","goal","backers"],axis=1)
df_ks = df_ks.dropna()
df_ks = df_ks.drop_duplicates()
df_ks["name"] = df_ks["name"].str.replace("(Canceled)"," ")
df_ks = df_ks.rename(columns={"usd pledged" : "usd_pledged"})

# %%
df_ks.head()
# Out:
#            ID                                               name  \
# 0   872782264           Scott Cooper's Solo CD "A Leg Trick" ( )
# 1  1326492673                                    Ohceola jewelry
# 2  1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3   156812982  SketchPlanner: Create and Plan- all in one bea...
# 4  1835968190    Proven sales with custom motorcycle accessories
#
#          category main_category             launched pledged       state  \
# 0            Rock         Music  2011-08-17 06:31:31    1145    canceled
# 1         Fashion       Fashion  2012-07-23 20:46:48    1851      failed
# 2  Tabletop Games         Games  2016-07-01 21:55:54    7534  successful
# 3       Art Books    Publishing  2017-08-28 15:47:02   16298  successful
# 4       Sculpture           Art  2016-01-25 17:37:10       1      failed
#
#   country usd_pledged  usd_pledged_real
# 0      US        1145       1145.000000
# 1      US        1851       1851.000000
# 2      US        3796       7534.000000
# 3      US        2670      16298.000000
# 4      CA    0.708148          0.738225

# %%
#Retyping
pd.to_numeric([df_ks["usd_pledged"],df_ks["pledged"]],errors="coerce")
df_ks.dropna()
# Out:
#                 ID                                               name  \
# 0        872782264           Scott Cooper's Solo CD "A Leg Trick" ( )
# 1       1326492673                                    Ohceola jewelry
# 2       1688410639  Sluff Off & Harald: Two latest EGGs are Classi...
# 3        156812982  SketchPlanner: Create and Plan- all in one bea...
# 4       1835968190    Proven sales with custom motorcycle accessories
# ...            ...                                                ...
# 149995   574841011  Scutes Headphones - A new way to listen to you...
# 149996   235190237                               My Drunk @$$ Reviews
# 149997   758540498          Freedom Planet - High Speed Platform Game
# 149998  1624952469                                      Clown vs Mime
# 149999   891117261                            Striker's Cafe & Bakery
#
#               category main_category             launched  pledged  \
# 0                 Rock         Music  2011-08-17 06:31:31     1145
# 1              Fashion       Fashion  2012-07-23 20:46:48     1851
# 2       Tabletop Games         Games  2016-07-01 21:55:54     7534
# 3            Art Books    Publishing  2017-08-28 15:47:02    16298
# 4            Sculpture           Art  2016-01-25 17:37:10        1
# ...                ...           ...                  ...      ...
# 149995  Product Design        Design  2014-10-14 20:44:37     3664
# 149996       Webseries  Film & Video  2012-04-18 04:42:47        0
# 149997     Video Games         Games  2013-01-16 00:53:32  25472.7
# 149998       Webseries  Film & Video  2011-04-27 01:22:52       76
# 149999     Food Trucks          Food  2016-04-03 08:01:57       29
#
#              state country usd_pledged  usd_pledged_real
# 0         canceled      US        1145       1145.000000
# 1           failed      US        1851       1851.000000
# 2       successful      US        3796       7534.000000
# 3       successful      US        2670      16298.000000
# 4           failed      CA    0.708148          0.738225
# ...            ...     ...         ...               ...
# 149995    canceled      US        3664       3664.000000
# 149996      failed      US           0          0.000000
# 149997  successful      US     25472.7      25472.690000
# 149998      failed      US          76         76.000000
# 149999      failed      US          29         29.000000
#
# [148516 rows x 10 columns]

# %% [markdown]
# ### Importer les données

# %%
DOCUMENTS = df_ks.to_dict("records")
collection.insert_many(DOCUMENTS)

# %%
database.list_collection_names()
# Out:
# ['kickstarter']

# %% [markdown]
# ## Question 1

# %%
five_max = collection.find().sort([("pledged",-1)]).limit(5)

for i in five_max:
    print(i)
# Out:
# {'_id': ObjectId('61af67a8f7a5cbe2d7478b96'), 'ID': 218218259, 'name': 'True North ï¿½ Repurposed Sailcloth Products', 'category': 'Product Design', 'main_category': 'Design', 'launched': '2016-05-10 15:53:56', 'pledged': '9996.0', 'state': 'successful', 'country': 'US', 'usd_pledged': '9996.0', 'usd_pledged_real': 9996.0}
# {'_id': ObjectId('61af67a8f7a5cbe2d7471346'), 'ID': 1742823215, 'name': 'Polco: A Digital Platform for Better Civic Communication', 'category': 'Web', 'main_category': 'Technology', 'launched': '2017-06-27 21:46:04', 'pledged': '9994.0', 'state': 'failed', 'country': 'US', 'usd_pledged': '876.0', 'usd_pledged_real': 9994.0}
# {'_id': ObjectId('61af67a8f7a5cbe2d746f95a'), 'ID': 1247285954, 'name': '2016 Gaming Calendar', 'category': 'Tabletop Games', 'main_category': 'Games', 'launched': '2015-06-26 14:57:14', 'pledged': '9994.0', 'state': 'successful', 'country': 'US', 'usd_pledged': '9994.0', 'usd_pledged_real': 9994.0}
# {'_id': ObjectId('61af67a8f7a5cbe2d7472c78'), 'ID': 796104705, 'name': 'The Girl in The Mountain - Film', 'category': 'Science Fiction', 'main_category': 'Film & Video', 'launched': '2015-08-31 02:11:11', 'pledged': '999.0', 'state': 'failed', 'country': 'GB', 'usd_pledged': '1537.65168912', 'usd_pledged_real': 1515.1974761875872}
# {'_id': ObjectId('61af67a8f7a5cbe2d746e240'), 'ID': 472451633, 'name': "Zip'n'Fly - Travel Jacket - The ultimate travel companion!", 'category': 'Design', 'main_category': 'Design', 'launched': '2017-03-30 17:40:37', 'pledged': '999.0', 'state': 'failed', 'country': 'GB', 'usd_pledged': '734.90618336', 'usd_pledged_real': 1292.6516827762898}

# %% [markdown]
# ## Question 2

# %%
success = collection.aggregate([{"$group" : {"_id":"$state", "state": {"$sum":1}}}])
list(success)
# Out:
# [{'_id': 'successful', 'state': 52998},
#  {'_id': 'canceled', 'state': 15350},
#  {'_id': 'live', 'state': 1132},
#  {'_id': '850.0', 'state': 1},
#  {'_id': 'suspended', 'state': 738},
#  {'_id': 'failed', 'state': 78297}]

# %% [markdown]
# ## Question 3

# %%
categories = collection.aggregate([{"$group" : {"_id":"$main_category", "main_category": {"$sum":1}}}])
list(categories)
# Out:
# [{'_id': 'Theater', 'main_category': 4305},
#  {'_id': 'Journalism', 'main_category': 1807},
#  {'_id': 'Photography', 'main_category': 4176},
#  {'_id': 'Comics', 'main_category': 4139},
#  {'_id': 'Art', 'main_category': 11260},
#  {'_id': 'Games', 'main_category': 13987},
#  {'_id': 'Publishing', 'main_category': 15721},
#  {'_id': 'Indie Rock', 'main_category': 1},
#  {'_id': 'Food', 'main_category': 9805},
#  {'_id': 'Fashion', 'main_category': 8943},
#  {'_id': 'Dance', 'main_category': 1488},
#  {'_id': 'Design', 'main_category': 11911},
#  {'_id': 'Film & Video', 'main_category': 24982},
#  {'_id': 'Music', 'main_category': 19657},
#  {'_id': 'Technology', 'main_category': 12871},
#  {'_id': 'Crafts', 'main_category': 3463}]

# %% [markdown]
# ## Question 4

# %% [markdown]
# ## Question 5

# %%
more_than = collection.find({"$and":[{"usd_pledged_real":{"$gt":200000}},{"country":"US"}]},{"name":1})
list(more_than)
# Out:
# [{'_id': ObjectId('61af67a7f7a5cbe2d745bb0b'),
#   'name': 'The uKeg Pressurized Growler for Fresh Beer'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745bb9a'),
#   'name': 'Redux COURG - Hybrid Watches with Missions to Tackle'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745bc47'),
#   'name': 'Legion Solar - A Better Way to Energy Independence'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745bd64'),
#   'name': 'Edyn: Welcome to the connected garden.'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745bd73'), 'name': 'Period Panties'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745be27'),
#   'name': 'Smartkase for iPhone 7 - Dual Sim +Memory Card +Battery Case'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745be5a'), 'name': 'Shadowrun: Hong Kong'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745bed0'),
#   'name': 'Kurt Vonnegut: Unstuck in Time'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745bf25'),
#   'name': 'Battle Worlds: Kronos - Turn-based strategy revisited'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745bfb8'),
#   'name': 'Hie Diaper Bag: Your New Best Friend'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745c011'),
#   'name': 'Hemingwrite - A Distraction Free Digital Typewriter'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745c093'),
#   'name': 'Dobot: Robotic Arm for Everyone, Arduino & Open Source'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745c11d'),
#   'name': 'ECLIPSE - Say Goodbye to Messy Cables'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745c355'),
#   'name': 'PolySmooth & Polysher: 3D Prints Without Layers'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745c471'),
#   'name': 'Sails of Glory - Miniatures Ship Combat'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745c518'),
#   'name': 'The Temperfect Mug: Coffee and Tea at The Perfect Temp'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745cc58'),
#   'name': 'Planetary Annihilation - A Next Generation RTS'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745cc91'),
#   'name': 'Volt Planner - Reach Your Goals in 2017'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745ccbf'),
#   'name': "Aeon's End: War Eternal"},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745ccfa'),
#   'name': 'XERISCOPE: The Orbiting Mechanical Automatic Watch by XERIC'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745cdb0'),
#   'name': 'Canary in a Coal Mine'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745cf30'),
#   'name': 'Akaneiro: Demon Hunters'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745d033'), 'name': 'MYTH: Journeyman'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745d048'),
#   'name': 'The ultimate sleep sanctuary: Kokoon EEG headphones'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745d14f'),
#   'name': "Iota: Never lose sight of what's important."},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745d15c'),
#   'name': 'Pixy (CMUcam5): a fast, easy-to-use vision sensor'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745d6e7'),
#   'name': 'Reissue of the 1975 NASA Graphics Standards Manual.'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745d781'),
#   'name': 'Unsung Story: Tale of the Guardians'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745daad'), 'name': 'Fugitive'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745dad8'),
#   'name': 'Radian 2: Time Lapse, Motion, and Wireless Camera Control'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745db42'),
#   'name': 'The Ultimate Sleep Travel Solution - NodPod'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745dc39'),
#   'name': "Notion: Be home, even when you're not."},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745dcc0'),
#   'name': 'Hoverboard: The Next Evolution in Personal Electric Mobility'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745dd40'),
#   'name': 'The Duchess - A Gaming Table from BoardGameTables.com'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745dd6f'),
#   'name': "World's First And Only Complete Weather Camera System"},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745dd9d'),
#   'name': 'Phantom Ice Maker | Seven Clear, Slow-Melting Ice Shapes'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745de71'),
#   'name': 'HUDWAY CAST. Keep your eyes on the road!'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e0bf'),
#   'name': 'Code Monkey Save World'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e0f8'),
#   'name': 'Worldï¿½s first roast-grind-brew coffee machine'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e1a1'),
#   'name': 'MagSphere & MagBounce Flash Diffusers - by MagMod'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e242'),
#   'name': 'Finex Cast Iron Skillet: A Beloved Classic Updated'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e271'),
#   'name': 'Ctrl+Alt+Del 1.0: The Box Set'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e2c7'), 'name': 'Art Story'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e308'),
#   'name': 'Vanguard of War - Archon Studio'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e4e9'),
#   'name': "H-Hour: World's Elite"},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e6b0'),
#   'name': 'Dungeon of Doom: Handcrafted Game Terrain by Dwarven Forge'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e936'),
#   'name': 'Click - The First Watch Band Adapter for Apple Watch!'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e99a'),
#   'name': 'Passion Planner: Get One, Give One'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745e9ad'), 'name': 'Kill Doctor Lucky'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745eb4a'),
#   'name': 'Be. | The First Battery-Free, Powered Toothbrush'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745eb5d'),
#   'name': 'Numenera: Into the Ninth World'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745eb7e'),
#   'name': 'ZRRO - Play 300,000 touch games on your TV!'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745eba2'),
#   'name': 'StoneTether - The Smallest Tracking Device at Long Range'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745ebb7'),
#   'name': 'Woobo: A Smart Companion for Curious Kids'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745ec97'),
#   'name': 'FormBox: A Desktop Vacuum Former That Makes Beautiful Things'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745ed7e'),
#   'name': 'Superior Motors: Community Restaurant & Farm Ecosystem'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745f0ce'),
#   'name': 'Modbook Pro X ï¿½ 15.4" Retina Quad-Core Mac OS X Tablet'},
#  {'_id': ObjectId('61af67a7f7a5cbe2d745f0e2'),
#   'name': 'Remix IO - A 4K, Nougat-powered, All-in-One device'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f260'), 'name': 'Fief - France 1429'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f2cf'), 'name': 'Posthuman'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f30a'),
#   'name': 'Luminoodle: Versatile USB Lighting Solution'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f3de'),
#   'name': 'Glowdeck - A companion for your smartphone.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f4d2'),
#   'name': 'tinyTesla: the Little Singing Tesla Coil Anyone Can Build'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f50c'),
#   'name': 'ZUNGLE : Wear the Beats'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f5a9'),
#   'name': 'colorspike - create in color'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f5de'),
#   'name': 'ORION4Sight: Sunglasses On Steroids'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f797'),
#   'name': 'Unknown Armies Third Edition Roleplaying Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f907'),
#   'name': 'Crowfall - Throne War PC MMO'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f916'),
#   'name': 'BIKI: First Bionic Wireless Underwater Fish Drone'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745f994'),
#   'name': 'Create wide-angle Bubble Bokeh: Trioplan 35+ Fine Art Lens'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745fcf3'),
#   'name': "Remix Mini - The World's First True Android PC."},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745fe09'),
#   'name': 'Zafirro. Sapphire Blade Razor.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745ff79'),
#   'name': 'Little Witch Academia 2'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745ff91'),
#   'name': 'Dead State: The Zombie Survival RPG'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d745ffa8'),
#   'name': 'Dobot M1: Pro Robotic Arm for Makers and Businesses'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746059d'),
#   'name': 'Wiral LITE | The Easy Cable Cam, For Impossible Film Shots'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746068e'),
#   'name': 'Dungeon Dice: THE LOST KING and Boxed Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7460749'),
#   'name': 'SnapJet: Turn your smartphone into a polaroid film printer!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74607a1'),
#   'name': 'BLAZAR: Aluminum Bluetooth Speaker & Artist Collaboration'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746085d'),
#   'name': "Halo Back: World's First Smart Screen Protector"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7460a17'),
#   'name': 'Rum & Bones: Second Tide'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7460bd9'),
#   'name': 'RE-LOAD by Archon Studio'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7460c3d'),
#   'name': 'The Mastery Journal: Master Productivity, Discipline & Focus'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7460d30'),
#   'name': 'The X Suit | The Suit of the Future.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7460d92'),
#   'name': 'Vue: Your Everyday Smart Glasses'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7460efe'),
#   'name': 'Girl Genius Volume 12 Printing and Reprint Frenzy!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7460fd4'),
#   'name': "World's First Custom Fit Sandals, 3D Printed in USA"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74610b2'),
#   'name': 'Project 562: Changing The Way We See Native America (Phase2)'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74610b6'),
#   'name': 'Deep Learning for Computer Vision with Python [ eBook ]'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74612a1'),
#   'name': "De La Soul's NEW ALBUM"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746134e'),
#   'name': 'SousVide Supreme Touch+'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7461440'),
#   'name': 'Machine of Death: The Game of Creative Assassination'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7461538'),
#   'name': 'DRAGON WARRIORS:   a feature film starring James Marsters'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74616ad'), 'name': 'Xeko'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74617e5'),
#   'name': 'Electric Objects: A Computer Made for Art'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746184b'),
#   'name': 'Sleep Shepherd Blue: A Sleep Tracker that HELPS You Sleep'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746190b'),
#   'name': 'Redefining Swiss Automatic Watches by LIV'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74619e8'),
#   'name': 'The Lomography Daguerreotype Achromat 2.9/64 Art Lens'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7461b17'),
#   'name': "PancakeBot - The world's first pancake printer!"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7461c50'),
#   'name': 'Game Anywhereï¿½ Table GAT-64 Plus Portable Gaming Table'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7461d56'),
#   'name': 'The Cyanide & Happiness Show'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7461e55'), 'name': 'LOAD the Board Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7461f13'),
#   'name': 'PARKE: Premium Active Denim - Engineered for Performance'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7461f27'),
#   'name': 'PENXO | The most minimalistic 2mm lead holder pencil'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746201f'), 'name': '1001 Knights'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746228f'),
#   'name': 'BedJet v2: Sleep inducing climate control just for your Bed'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746233c'),
#   'name': 'Kniterate: The Digital Knitting Machine'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74625b8'),
#   'name': 'RiffTrax will Riff GODZILLA & ANACONDA in Cinemas Nationwide'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7462652'), 'name': 'PocketScan'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746270f'),
#   'name': 'Bios Genesis 2nd edition. Begin, evolve, conquer!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74627ec'),
#   'name': 'Kiwi 3 - OBD Car to Smartphone Interface Reinvented'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7462824'),
#   'name': 'The Rocketbook Everlast Notebook'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74628bd'),
#   'name': "Boss Fight Studio's Vitruvian H.A.C.K.S. Action Figures"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7462a05'),
#   'name': 'SpeedX Leopard | the first ever smart aero road bike'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7462af0'),
#   'name': 'Ticwatch S & E: A Truly Optimized Smartwatch'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7462b3d'),
#   'name': 'RiffTrax Live 2015: THE ROOM, MIAMI CONNECTION, SHARKNADO 2!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7462bf4'),
#   'name': '"Be Here Now" ï¿½ The Andy Whitfield Story'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7462f66'),
#   'name': 'Dreamcade Replay - One Console To Rule Them All'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463004'),
#   'name': 'The Neck Hammock - Better Neck Pain Relief at Your Door'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74630ab'),
#   'name': 'XPUMP | TURN ANY SOUND SOURCE INTO A HOME THEATER EXPERIENCE'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74630d2'),
#   'name': 'Pico C - Craft Brewing For All'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463128'),
#   'name': 'Nise Wave | WiFi Sous Vide with Adaptive Temperature Control'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74631a5'),
#   'name': 'Super Dungeon Explore: Legends'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74631eb'),
#   'name': 'ALCHEMA: Turn Fruit into Personalized Craft Cider'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746326d'),
#   'name': 'LunaR, the worldï¿½s first solar powered smartwatch.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463274'),
#   'name': "CHIP - The World's First Nine Dollar Computer"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74633f5'),
#   'name': 'New Studio Album from Toad the Wet Sprocket!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74634dc'),
#   'name': 'Capture Camera Clip System'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74634f8'),
#   'name': '3Dsimo mini - Make your vision come true'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74636b2'),
#   'name': 'FUGU LUGGAGE: One Case For All Your Needs'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74636fc'),
#   'name': 'Artisan Dice Does Handcrafted Polyhedrals'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463772'),
#   'name': 'MagBeam - Fresnel Lens Flash Extender + Gobos, by MagMod'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74637a8'),
#   'name': 'Raise3D 3D Printers - Raise the Standard of 3D Printing'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74637b6'), 'name': 'Sine Tempore'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746390d'),
#   'name': 'UBIK UNO: The Bezeless Smartphone at an Unbeatable Price'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74639dd'),
#   'name': 'MAGBELT - A magnetic belt that fits perfectly to your waist.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463b65'),
#   'name': 'Beasts of the Mesozoic: Raptor Series Action Figures'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463bc1'),
#   'name': 'ADV3NTURE HOODIE with 23 Pockets and Features!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463c90'),
#   'name': "Beastgrip Pro the world's best camera rig for smartphones"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463d05'),
#   'name': 'Karmaka ï¿½ A tactical card game for 2-4 souls'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463d11'),
#   'name': 'Revols - Premium Quick Custom-Fit Wireless Earphones'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463d18'), 'name': 'Princess Awesome'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463d59'),
#   'name': 'HAVOK - Disrupting Luxury Watches'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463e4f'),
#   'name': 'Saving Capitalism - Starring Robert Reich'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463ee6'),
#   'name': 'goTenna Mesh: Off-Grid, People-Powered Connectivity Anywhere'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7463f73'), 'name': 'The Perfect Notebook'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464023'), 'name': 'Grim Dawn'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74641d3'),
#   'name': 'Portable Console for PC games - PGS'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464222'),
#   'name': 'Fuel3D: A handheld 3D scanner for less than $1000'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464249'),
#   'name': "HelloEar Arc: The World's Most Comfortable Custom Earphones"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74643b9'),
#   'name': 'The BIG Turtle Shellï¿½: Rugged, Wireless BoomBox & Power Bank'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464450'),
#   'name': 'BOMBERCO.COM - "Best Damn Duffel Bag"'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74645cc'),
#   'name': "Loog Pro & Loog Mini: The ultimate beginners' guitars"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464667'),
#   'name': 'Fairytale Games: The Miniatures Campaign'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464909'),
#   'name': 'Gocycle - the BEST folding electric bike in the world!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464927'),
#   'name': 'KNK Force - The first dual head plotter with a true Z axis'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464962'),
#   'name': 'Cubibot: The new standard of modern consumer 3D printer'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464a3e'),
#   'name': 'Lightpack ï¿½ ambient backlight for your displays'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464b4a'),
#   'name': 'Onewheel :: The Self-Balancing Electric Skateboard'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464c34'),
#   'name': 'Introducing the Airdog ADII: The Future is Hands-Free'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464cb8'),
#   'name': 'Quarter Century Watch | Disrupting Luxury Watches'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464db3'),
#   'name': 'MicroView: Chip-sized Arduino with built-in OLED Display!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464dde'),
#   'name': 'Onion Omega: Build Hardware with JavaScript, Python, PHP'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464e29'),
#   'name': 'The Dice Tower - 2016 (Season 12)'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464e98'),
#   'name': 'Ghostbusters: The Board Game II'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464ef6'),
#   'name': 'NASA Inspired Kitchen Knives with Patented Technology'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7464f50'),
#   'name': 'Spike : Laser accurate measurement & modeling on smartphones'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746504e'),
#   'name': 'Genesis 3D Printer: The machine of the future'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465156'), 'name': 'Offer & Compromise'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465190'),
#   'name': 'THE ERGO Posture Transformer | Perfect Posture Instantly'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465314'),
#   'name': 'YOKOHAMA Deluxe! by Hisashi Hayashi & TMG'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74653bb'), 'name': 'Ravine'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465684'),
#   'name': 'RED ASH - The Indelible Legend'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465761'),
#   'name': 'Medical Inc. The Movie'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746590d'),
#   'name': 'Near and Far: Amber Mines'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746598e'),
#   'name': 'Boss Monster: the Dungeon-Building Card Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465b97'),
#   'name': 'The Spark Planner - Achieve all your goals in 2016'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465cac'),
#   'name': 'Darma: Sit smart for a healthy body and mind'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465d3c'),
#   'name': "Ogre Designer's Edition"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465e2a'),
#   'name': 'THE RED PILL - a documentary film'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465f4a'),
#   'name': 'iControlPad 2 - The open source controller'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465f4d'),
#   'name': 'ODOï¿½| Self-Cleaning Jeans & Tees Woven With Silver'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465fdc'),
#   'name': 'LYFE - Set your plants free'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7465fe2'),
#   'name': 'Three New Treasure Chests of Realistic Resource Tokens'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7466000'),
#   'name': 'Chaos Reborn - From the Creator of the Original X-COM'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746607d'),
#   'name': 'Pathologic (???.??????)'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74660f1'),
#   'name': 'KAMMOKï¿½: no longer bound to the ground'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74661a3'),
#   'name': 'STEM System: The Best Way to Interact with Virtual Worlds'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74661d2'),
#   'name': 'VET Tv - Streaming TV network for post 9/11 veterans'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746649d'), 'name': 'Shadowrun Online'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746655f'),
#   'name': 'Trainerbot: Smart Table Tennis Robot'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74665c0'),
#   'name': 'Siege of the Citadel - 2nd Edition Techno Fantasy Boardgame'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7466610'), 'name': 'NeoLucida XL'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74666b4'), 'name': 'Relic Knights'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746675e'),
#   'name': 'Gather: The minimal, modular organizer that cuts clutter'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74667a8'),
#   'name': 'The Sunrise Smart Pillow: Sleep Smart. Wake Naturally.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7466859'),
#   'name': 'TRAKLINE EXPRESS BELT'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74669a3'),
#   'name': 'Pulse - Your Camera, Upgraded.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7466afe'),
#   'name': 'HEATWORKS MODEL 1: Your next water heater!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7466c03'),
#   'name': "Ava's Demon: Book One"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7466ccd'), 'name': 'The Searzall'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7466db6'),
#   'name': 'The Pocket TV: Makes any TV a Smart TV'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7466f09'), 'name': 'The Bill Nye Film'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7467104'),
#   'name': 'The Best Tent/Hammock: Inspired by Travel || Crua Hybrid'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746732c'),
#   'name': 'Shroud of the Avatar: Forsaken Virtues'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7467387'),
#   'name': "3Doodler: The World's First 3D Printing Pen"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74676e6'),
#   'name': 'Cora Ball - Microfiber Catching Laundry Ball'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74676f7'),
#   'name': 'Waylens - A Data Driven Automotive Camera System'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746770d'),
#   'name': 'The Art of J.A.W. Cooper: Three Book Set With Prints'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746774e'),
#   'name': 'Chronicle X by Archon Studio'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7467768'),
#   'name': 'The Newest Hottest Spike Lee Joint'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74679cd'),
#   'name': 'Grove Ecosystem - Grow Fresh Food In Your Home'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7467aee'),
#   'name': 'ButcherBox: Open your door to healthy, 100% grass-fed beef'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7467c64'),
#   'name': 'MARTIAN ï¿½ Voice Command Watches for iPhone & Android'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7467dee'), 'name': 'Fate Core'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468031'),
#   'name': '2015 CES Best, First Domestic Robot That Tracks Intruders!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468173'),
#   'name': 'The Lomography Petzval Portrait Lens'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74681ea'),
#   'name': 'Space Monkey: Taking the cloud out of the datacenter'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74681fb'),
#   'name': 'Anamanaguchi - make ENDLESS FANTASY more than an album!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74681ff'),
#   'name': 'Cinefex Classic Collection for iPad'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468438'),
#   'name': 'Bernie Sanders Action Figure'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468473'),
#   'name': 'Open qPCR: DNA Diagnostics for Everyone'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468656'),
#   'name': 'Bold Dress Shoes Designed To Get Compliments'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74686b9'), 'name': 'Unfair'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746886b'),
#   'name': 'Cubiio: The Most Compact Laser Engraver'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746888e'),
#   'name': 'Monkey Light: The most effective way to be seen on your bike'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74689a9'),
#   'name': 'CLANNAD Official English Release'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74689af'),
#   'name': 'Trailhead Adventure Pant | Packable, Durable, & Stain Proof'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468aa7'), 'name': 'Rise to Nobility'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468b18'),
#   'name': 'New Solar Technology to Build an Underground Park'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468bc5'),
#   'name': 'Blood and Plunder: No Peace Beyond the Line'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468c30'),
#   'name': 'The Perfect Beer Drinking Vessel and Private Keg!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468c66'),
#   'name': 'Deadzone: The Sci-fi Miniatures Board Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468f54'),
#   'name': 'BetterBack - Perfect Posture Effortlessly'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7468fa8'),
#   'name': 'BRIDEGROOM - An American Love Story'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469028'),
#   'name': 'HEXA: Programmable, Highly Maneuverable Robot'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469054'),
#   'name': "The Lomo'Instant Automat Camera"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74690e5'),
#   'name': 'Leash and Cuff, by Peak Design'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469165'),
#   'name': 'Penny Arcade\'s Podcast, "Downloadable Content": The Return'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74692fc'), 'name': 'What Do You Meme?ï¿½'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469414'),
#   'name': 'HICKIES 2.0 - The Evolution of Shoelaces'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469430'),
#   'name': 'Pono Music - Where Your Soul Rediscovers Music'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469481'),
#   'name': 'Carbon Fiber Acoustic Electric Guitars | KLOS Guitars'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74694fc'),
#   'name': 'Mizu | The Future of Towels'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469582'),
#   'name': 'Une Bobine - For People Who Love iPhone... and Android'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74695e5'),
#   'name': 'Storium ï¿½ The Online Storytelling Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746975c'),
#   'name': 'The Veronica Mars Movie Project'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469774'),
#   'name': 'WAVES Nx ï¿½ 3D AUDIO ON ANY HEADPHONES'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74697cb'),
#   'name': 'SilverAir Sock - Odorless Socks Made With Pure Silver'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74699e8'), 'name': 'HAND Stylus'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469a7e'),
#   'name': 'nexpaq: the first truly modular smartphone case'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469aee'),
#   'name': 'The COMPLETE Girls With Slingshots!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469cf0'),
#   'name': 'Shadows of Brimstone: Forbidden Fortress'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469d0c'),
#   'name': 'E370 Quad Morphing VCO'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469e38'),
#   'name': 'A New Way To Buy a Luxury Watch'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469e69'),
#   'name': 'OVERLOAD - The Ultimate Six-Degree-of-Freedom Shooter'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469ef6'),
#   'name': "New, compact, step-driven vehicle. It's your move!"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7469f59'),
#   'name': 'Rekonect Notebook: The Magnetic Lifestyle'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a06a'),
#   'name': 'Air Bonsai | Create your "little star"'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a1be'),
#   'name': '"Period of Happiness"'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a2f7'), 'name': 'SOWATCH'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a378'),
#   'name': 'HyperDriveï¿½ Compact Thunderbolt 3 USB-C Hub for MacBook Pro'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a54c'),
#   'name': 'The Neptune Convertible Art Lens System'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a589'),
#   'name': "iKeybo: World's Most Advanced Projection Keyboard and Piano"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a7b0'),
#   'name': 'Napoli Multi-Fueled Outdoor Pizza Oven'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a7ef'),
#   'name': 'HEATED Ultra-Light 80g Mid-Layer | Make ANY Jacket Sub-Zero'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a972'),
#   'name': 'The Tomorrow Girl: Dresden Codak Volume 1'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746a99f'),
#   'name': 'HEX MMO Trading Card Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746aab3'),
#   'name': 'NEEO - The Thinking Remote'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746aaf1'),
#   'name': 'HDHomeRun DVR. The DVR re-imagined.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746ac42'),
#   'name': 'Chronicles of Elyria - Epic Story MMORPG with Aging & Death'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746af06'),
#   'name': 'Penny Arcade Sells Out'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746b04c'),
#   'name': 'BACKPAIX: stylish, versatile, the best backpack for commuter'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746b127'),
#   'name': 'BetterBack Therapy: Improve Posture + Back Pain'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746b29b'),
#   'name': 'Cerebria - The Inside World'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746b364'),
#   'name': 'The Flame in the Flood'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746b456'),
#   'name': '"The Wrecking Crew" The Untold Story of Rock & Roll Heroes'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746b468'),
#   'name': "Rumpl - The World's Best Blanket"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746b59b'),
#   'name': 'The Dash ï¿½ Wireless Smart In Ear Headphones'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746b5da'),
#   'name': 'CRYAMORE! A True, First-Class Take on the Action-RPG Genre'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746b992'), 'name': 'Rappan Athuk'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746ba83'),
#   'name': "ODIN: Android 'Smart' Projector to Carry in Your Pocket"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746bb3e'),
#   'name': 'MOSS - The Dynamic Robot Construction Kit'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746bbb2'),
#   'name': 'One Deck Dungeon: Forest of Shadows'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746be4b'),
#   'name': 'Super Dungeon Explore: Forgotten King'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746bec8'),
#   'name': 'Pegasus Touch Laser SLA 3D Printer: Low cost, High Quality'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746bf54'),
#   'name': 'Neuroon Open: Smartest Sleep, Dream and Meditation Device'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746bfc9'),
#   'name': 'BuildOne: $99 3D Printer w/ WiFi and Auto Bed Leveling!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746c024'), 'name': 'The Nomad CNC Mill'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746c083'),
#   'name': '"All-American Boy" - The Album'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746c2f7'),
#   'name': 'eleMount : Premium Mount / Stand for iPhone, iPad, Android'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746c40a'),
#   'name': 'GEEK: A New USB Awesomifier for Headphones'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746c4f4'),
#   'name': 'Somabar: Robotic Bartender for your Home'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746c657'),
#   'name': 'Vufine: a Handsfree Wearable Display'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746c797'),
#   'name': 'The Unstainableï¿½ White Shirt'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746c932'), 'name': 'ILLIMAT'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746c943'),
#   'name': 'mBot: $49 educational robot for each kid'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746cae5'), 'name': 'BATTLETECH'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746cc24'), 'name': 'Rise of Tribes'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746cca2'),
#   'name': 'The GoBoat. Personal, Portable Watercraft'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746ced1'),
#   'name': 'SilverAir: Travel Underwear Engineered With Pure Silver'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746cfb9'),
#   'name': 'Cut The Cord with the Simple.TV DVR.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746d24e'),
#   'name': '3D 5.1 Virtual Surround Sound Earbud with Premium Sub Bass'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746d314'), 'name': 'Rum & Bones'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746d5d6'),
#   'name': 'IllumiBowl 2: Toilet Night Light SharkTank Upgrade! Only $10'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746d5db'),
#   'name': "Infento: World's First Real Constructible Rides"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746d683'),
#   'name': "FLOATTI - The World's First SUPER SUITCASE"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746d750'),
#   'name': 'Heroes of Land, Air & Sea - Featuring Pre-Painted Miniatures'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746d87f'),
#   'name': "Hercules - The World's Smallest Camera Motion Control System"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746d996'),
#   'name': 'Goliath CNC - An Autonomous Robotic Machine Tool for Makers'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746da62'),
#   'name': 'GoSun Go: Boil Water, Cook Meals, Go Anywhere'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746da7c'), 'name': 'Yomi'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746dbaf'), 'name': 'The Bards Tale IV'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746dc05'),
#   'name': 'Pico - Craft Beer at Home'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746dc47'),
#   'name': 'The HuMn Wallet - the best minimal RFID blocking wallet'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746dc4b'),
#   'name': 'Catalyst - Worldï¿½s Most Advanced Wireless Earbuds'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746dc79'),
#   'name': 'Polar Ice Tray: The Perfect Ice for the Perfect Drink!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746dd0a'),
#   'name': 'GeeFi | Unlimited 4G Wi-Fi Everywhere You Travel'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746dd24'),
#   'name': 'Make Any Headphones Wireless - Jack by Podo Labs'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e02e'),
#   'name': 'TheoryBoard | Music Theory Made Easy'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e08f'),
#   'name': 'THE AGENTS - A Double-edged Cards Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e2fa'),
#   'name': "COOLEST COOLER: 21st Century Cooler that's Actually Cooler"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e303'),
#   'name': 'Endangered Orphans of Condyle Cove'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e323'), 'name': 'The Floyd Leg'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e52e'),
#   'name': 'Ti Arto : The Ultimate Refill Friendly Pen'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e6cd'),
#   'name': 'The New ilumi. A Better Smartbulb.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e717'), 'name': 'Golem Arcana'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e7c4'),
#   'name': 'Masaaki Yuasa\'s "Kick-Heart"'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e801'), 'name': 'Escape Big Box'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e84f'), 'name': 'Banner Saga 3'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746e933'),
#   'name': 'SoftPanels LED Lights with Intelligent/Precise Color Control'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746eafa'), 'name': 'The Diaper Bag'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746ec55'),
#   'name': 'SHARKWATER: EXTINCTION'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746ecb8'),
#   'name': 'Muv-Luv: A Pretty Sweet Visual Novel Series'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746ed38'),
#   'name': 'Trunkster: Zipperless Luggage with GPS + Battery + Scale'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746edad'),
#   'name': 'Snapmaker : The All-Metal 3D Printer'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746f076'),
#   'name': 'ARCANA HEART 3 LOVE MAX SIX STARS!!!!!! | 2D fighting game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746f157'),
#   'name': 'EverDock: iPhone 5S, 5C, 5, 4, iPad, iPad Mini, Android Dock'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746f16a'),
#   'name': 'Vinci 2.0 - Worldï¿½s First Standalone AI Sports Headphones'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746f587'),
#   'name': 'Acteon Compression Packing Cubes'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746f6fa'), 'name': 'Alice: Otherlands'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746f703'),
#   'name': 'Solid Titanium Pen + Stylus'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746fb5e'),
#   'name': 'COBI. Worldï¿½s Smartest Connected Biking System.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746fb98'), 'name': 'TAKEDOWN'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746fba3'),
#   'name': 'The Super Fleece by Rumpl: The Perfect Blanket for Your Bed'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746fd6c'),
#   'name': "Aurai-The World's 1st Cool/Warm Water-propelled Eye Massager"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746fda7'),
#   'name': 'OURA ring. Improve sleep. Perform better.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746fdaa'),
#   'name': "CST-01: The World's Thinnest Watch"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746fdab'),
#   'name': 'Buhel Tech Sunglasses + Headphones: No Earphones Or Wires!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746fec3'),
#   'name': 'OLO - The First Ever Smartphone 3D Printer.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d746ff9a'),
#   'name': 'Sphericam 2, the 4K 360? Video Camera for VR'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747000f'),
#   'name': 'Mythic Legions Action Figures by Four Horsemen Studios'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747003f'),
#   'name': 'Titan 1: Fastest, Tallest Print, High Res SLA 3D Printer'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74700a1'),
#   'name': 'EcoQube C- Your Window to Nature!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74700d7'),
#   'name': 'Ablyï¿½ | Unbelievably odor & stain repellant natural apparel'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470134'),
#   'name': 'TOUCH TIME: Digital Watch with Touch Screen'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747014b'),
#   'name': "101Hero: The World's First $49 3D Printer"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74701a6'),
#   'name': 'Codex Silenda: The Book of Puzzles'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74702bd'),
#   'name': 'Cubetto - Hands on coding for ages 3 and up'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470444'),
#   'name': 'Zombicide: Green Horde'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74704a5'),
#   'name': 'Solowheel Iota: A Mini Personal E-Vehicle'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74704f8'),
#   'name': 'Orbitkey 2.0 - Carry Your Keys Better'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74705d4'),
#   'name': 'Vi. The First True Artificial Intelligence Personal Trainer'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74707a4'),
#   'name': 'GNARBOX: Edit & Share HD Footage in Seconds - Laptop Free'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74707ad'),
#   'name': 'Firestarter Survival Bracelet / Carabiner Paracord Keychain'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74707f6'), 'name': 'THE BOUNCE BACK ( )'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747081e'),
#   'name': 'Ministry of Supply: The Future of Dress Shirts.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470852'),
#   'name': 'AXEL. Modular headphones with a difference: Soundscapes.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74708e6'),
#   'name': 'Makeblock Neuron: An Electronic Building Blocks Platform'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470968'),
#   'name': 'Magnic Light iC - Intelligent Contactless Bicycle Dynamo'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74709ad'),
#   'name': 'Vinhos Deluxe Edition: Like fine wine, age has improved it!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470a39'),
#   'name': 'Chameleon Pens Color Tops: Seamless Color To Color Blends'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470a74'),
#   'name': 'Folklore: The Affliction (2nd Printing)'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470b8e'),
#   'name': 'Henty CoPilot: First Two Bag System for Commuting & Travel'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470ba0'),
#   'name': 'Fate of the Elder Gods - the boardgame of Lovecraftian cults'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470bd2'),
#   'name': 'RiffTrax Wants to Riff TWILIGHT Live in Theaters Nationwide!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470c4e'), 'name': 'The Banner Saga'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470d28'),
#   'name': 'Bring THE WINGFEATHER SAGA to the Screen!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470e25'), 'name': 'STRAFEï¿½'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7470ec0'), 'name': 'Geode from iCache!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7471006'),
#   'name': 'Torment: Tides of Numenera'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74710a3'),
#   'name': 'THE 10-YEAR HOODIE: Built for Life, Backed for a Decade!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74712e9'),
#   'name': 'NORTH DRINKWARE : Mt. Hood, The Oregon Pint Glass'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74714c3'),
#   'name': "BULLET | World's Smallest LED Flashlight"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7471509'),
#   'name': "AGENT: The World's Smartest Watch"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74717ad'),
#   'name': 'FlowMotion Smartphone Stabilizer | The End of Shaky Videos'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747180e'),
#   'name': 'Neil deGrasse Tyson Presents: Space Odyssey - The Video Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747195a'),
#   'name': 'The VAVA Dash Cam: Capture the Road Ahead'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747198e'),
#   'name': 'Travail: Democratizing Fine Dining in Robbinsdale, MN'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74719a5'),
#   'name': 'FLUX All-in-One 3D Printer - UNLIMITED. ELEGANT. SIMPLE.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7471ab9'),
#   'name': 'Hackaball - A computer you can throw'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7471ad1'),
#   'name': 'Tiny Epic Galaxies: Beyond the Black'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7471b2e'),
#   'name': 'runScribe: Wearable for the Data-Driven Athlete'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747205d'), 'name': 'NEKOPARA Anime OVA'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472275'),
#   'name': 'Picbot - An Automated Motorized Picture And Video Bot'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472319'), 'name': 'Too Many Bones'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747239b'), 'name': 'XenoShyft: Dreadmire'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472479'),
#   'name': 'Starfinder Masterclass Miniatures'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472570'),
#   'name': 'Knocki: Make Any Surface Smart'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74725f7'),
#   'name': 'Steadicam Volt Smartphone Stabilizer | Shake-Free Videos'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472723'), 'name': 'Tesla vs. Edison'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472753'), 'name': 'Lightseekers'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74727fc'),
#   'name': 'Radiotopia: A Storytelling Revolution'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74728ce'),
#   'name': 'iStickï¿½: USB Flash Drive with Lightning for iPhone and iPad'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472ad7'),
#   'name': 'PowerUp FPV - Live Streaming Paper Airplane Drone'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472b79'), 'name': 'Implosion: ZERO_DAY'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472b87'),
#   'name': 'All Quiet on the Martian Front, Miniature Tanks vs Tripods'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472fa6'),
#   'name': 'Muzo - Your Personal Zone Creator with Noise Blocking Tech.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7472fe4'), 'name': 'Munchkin Shakespeare'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74731d7'),
#   'name': 'Conan: The Book of Set'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747333c'),
#   'name': 'WarStages: The Gothic Cathedral'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7473349'),
#   'name': 'The New Glif: A Tripod Mount for Smartphones, Redesigned'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74734bd'),
#   'name': 'Qmote: The Water-Resistant Internet Remote for Smartphones'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74735dc'),
#   'name': 'POWERUP DART - App Controlled Paper Airplane. With Tricks.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747364f'),
#   'name': 'Dust: Operation Babylon'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74737da'),
#   'name': 'Mistbox: Energy-saving device proven to cut AC bills by 30%'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7473873'),
#   'name': 'GameStick: The Most Portable TV Games Console Ever Created'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747387f'),
#   'name': 'Parallella: A Supercomputer For Everyone'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7473c0d'),
#   'name': 'ANIMUSIC 3 (DVD / Blu-ray)'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7473cb7'),
#   'name': 'Sea x Sky - The Waterproof Backpack That Fits In Your Pocket'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7473d24'),
#   'name': 'Pebble 2, Time 2 + All-New Pebble Core'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7473d5c'),
#   'name': 'ANTVR KIT: All-IN-ONE Universal Virtual Reality Kit'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7473d6e'),
#   'name': "OLIVERS: The Last Pair of Athletic Shorts You'll Ever Need"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7473dd7'),
#   'name': "BLOCKS - The World's First Modular Smartwatch"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747403f'),
#   'name': 'TruForce Collectibles: Mega Man X Action Figure'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74740d7'),
#   'name': 'Veydra - M4/3 Cinema Lenses for GH4 and BMPCC'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74742d6'),
#   'name': "Mind's Eye Theatre: Vampire The Masquerade"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747430b'),
#   'name': 'OpenROV Trident - An Underwater Drone for Everyone'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74743a8'),
#   'name': 'Nurugo Micro : The Smallest 400x Microscope for Smartphone'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474466'),
#   'name': 'Luxor 2 - The Flashlight Perfected'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747447c'),
#   'name': 'Awaken the Legendary Soap Bubble Bokeh: Trioplan f2.9/50'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74744ae'),
#   'name': 'Marina Abramovic Institute: The Founders'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474533'),
#   'name': 'Anatomy of Melancholy: The Best of A Softer World'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474591'),
#   'name': 'The Menstrual Cup, Reinvented | Lily Cup Compact'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747469e'),
#   'name': 'Empires of the Void II'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474713'),
#   'name': 'Marauder Task Force 1:18th K9 Dog, Exo Suit & Contract-Ops!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74747e4'),
#   'name': 'Solar-Breeze Next Generation Solar Robotic Pool Cleaner'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747499c'), 'name': 'BATBAND'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74749bf'),
#   'name': "Boosted Boards - The World's Lightest Electric Vehicle"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474aba'),
#   'name': 'The Legend of Korra: Pro-bending Arena'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474b12'),
#   'name': 'Articulated Icons: The Feudal Series - Ninja Action Figures'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474c59'),
#   'name': 'Volta - This is more than your average electric bicycle'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474cd5'),
#   'name': 'Silic : A shirt that cleans itself.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474d12'),
#   'name': 'GIR Tongs + Whisks | Squeeze. Lock. Whisk. Repeat.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474d14'),
#   'name': 'The New Garden Tower - Powering a Fresh Food Revolution'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474d47'),
#   'name': 'Robo C2 and Robo R2 Smart 3D Printers'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474ea0'),
#   'name': 'Sevenhugs Smart Remote: The First Remote for Everything'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7474f1c'),
#   'name': 'pixelstick - Light painting evolved.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7475083'),
#   'name': 'DreamForge-Games model kit. Something wicked this way comes!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74750e7'),
#   'name': '"This is Fine" Plush Dog.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747535d'),
#   'name': 'Talon - ultra lightweight pocket tool for everyday carry'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7475536'),
#   'name': "Lisboa: Vital Lacerda's New Game of Rebuilding & Influence"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74755e7'),
#   'name': 'Gothitropolis Raven Action Figure by Four Horsemen Studios'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74755e8'), 'name': 'Codex'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747561c'),
#   'name': "Wishbone: The World's Smallest Smart Thermometer"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74757ee'), 'name': 'New55 FILM'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747586f'), 'name': 'MYTH'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7475fec'), 'name': 'STARFIGHTER INC.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74760b0'), 'name': 'Kaosball'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7476115'), 'name': 'The Zen Habits Book'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747611f'),
#   'name': 'Galileo. Your iOS in Motion.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7476161'),
#   'name': 'The Best Workout Shirt Ever Made. Guaranteed.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7476179'),
#   'name': 'Crystal Wash 2.0: Clean Laundry with No Detergents'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7476215'), 'name': 'CA7CH Lightbox'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74762b0'),
#   'name': 'Mindset: smart headphones that improve your concentration'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74762bc'),
#   'name': "TAB | the world's most versatile convertible bag."},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7476355'),
#   'name': 'Pakayak - The Ultimate Packable Kayak'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747638c'),
# ...
#  {'_id': ObjectId('61af67a8f7a5cbe2d74781d0'),
#   'name': 'The ZBoard: The Weight-Sensing Electric Skateboard'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747824b'),
#   'name': 'HiddenRadio2 Bluetooth MultiSpeaker'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74783fb'),
#   'name': 'Angee. The First Truly Autonomous Home Security System.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478410'),
#   'name': 'tadoï¿½ Cooling - Intelligent AC control'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478646'),
#   'name': 'myIDkey: Passwords at the tip of your finger'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74786cf'),
#   'name': 'OrganATTACK! - a Card Game by The Awkward Yeti'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478918'),
#   'name': 'Limeade Blast 18,000mAh Ultra-High Capacity Battery Pack'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478aa6'),
#   'name': 'Robin. The smarter smartphone.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478b40'),
#   'name': 'RuneQuest: Classic Edition'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478bca'),
#   'name': 'AB | Smart, Automated Craft Beer Home Brewery'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478c02'), 'name': 'The Game Canopyï¿½'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478ca0'),
#   'name': 'The World of SMOG: Rise of Moloch'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478d2d'),
#   'name': 'NOLO: Affordable Motion Tracking For Mobile and SteamVR Play'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478d82'),
#   'name': 'Dashbot: Add AI to Any Car for $49'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478de6'),
#   'name': 'Mare Nostrum - Empires'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478ea6'), 'name': 'Dice Rings'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478edc'),
#   'name': 'Edible Cutlery: The Future of Eco Friendly Utensils'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478f11'),
#   'name': 'Taskin Kompak: The Easy Way to Pack More & Mess Less'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478f3b'),
#   'name': 'XPlotter - Desktop Plotter, Laser Cutter and Engraver'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7478fa9'),
#   'name': 'Folklore: The Affliction'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7479006'),
#   'name': 'Sentri: Welcome to a Smarter Home'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7479085'),
#   'name': 'eVscope | 100 times more powerful than a classical telescope'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74792e0'),
#   'name': 'The Field Study Handbook'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74793cb'),
#   'name': 'UP FRONT the card game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74793cc'),
#   'name': 'Passion Planner Eco: Growing Together.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747948e'),
#   'name': 'Plugfones - Bluetooth Earplug Headphones - Music Calls Quiet'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74794a0'),
#   'name': 'Digispark - The tiny, Arduino enabled, usb dev board!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74794b9'),
#   'name': 'ROLL PLAYER - Monsters & Minions Expansion (+ Reprint)'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747952f'),
#   'name': 'Kano: A computer anyone can make'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747967d'),
#   'name': "Chuck Palahniuk's Lullaby"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7479710'),
#   'name': 'Deltaprintr - A simple, affordable 3D Printer!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7479716'), 'name': 'Between Two Cities'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74797c7'),
#   'name': 'Tiny Epic Defenders: The Dark War & TED 2nd Edition'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7479898'),
#   'name': 'The Hughes - Aerospace Grade Titanium Aviator Sunglasses'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74798db'),
#   'name': 'Senstone, the Intelligent Wearable Voice Recorder'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d74799b4'),
#   'name': "PUGZ-World's smallest wireless earbuds charged through phone"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7479a53'),
#   'name': 'Age of Empires III is reborn as Empires: Age of Discovery'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7479c33'), 'name': 'Massive Darkness'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7479c56'),
#   'name': 'Ghostbustersï¿½: The Board Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d7479f90'),
#   'name': 'YARRA 3DX: The Most Advanced 3D Audio System In The World'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747a01e'),
#   'name': "A leather belt to last a lifetimeï¿½two if you count the cow's"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747a0ac'),
#   'name': 'Carvey: The 3D carving machine for the maker in all of us'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747a217'),
#   'name': 'GUSTIN: Redefining premium menswear, starting with denim.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747a265'),
#   'name': 'Minecraft: The Story of Mojang'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747a413'), 'name': 'Scythe'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747a5b3'),
#   'name': 'Marlon: Connected, Compression Carry-on'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747a714'),
#   'name': 'The Game Anywhere Table'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747a89e'), 'name': 'The Culture High'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747a981'),
#   'name': 'Precision Coffee Grinder: Better Grind, More Flavor'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747aac3'),
#   'name': 'Ashes of Creation ~ New MMORPG by Intrepid Studios'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747abe9'),
#   'name': 'Nomiku: bring sous vide into your kitchen.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747ad38'),
#   'name': 'Nimb: A Smart Ring that Keeps You Safe and Sound'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747ad41'),
#   'name': 'cookooï¿½ - the watch for the connected generation'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747af5d'),
#   'name': 'Penna - Retro Bluetooth Keyboard, Starting as low as $99'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747afe9'),
#   'name': 'BOLT DRONES ï¿½ INTRODUCING A WHOLE NEW FLIGHT EXPERIENCE'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b125'),
#   'name': '?VAGO?Best travel tool.Give you more than 50% luggage space!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b263'),
#   'name': 'Public Goods ï¿½ Revolutionizing Household Products'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b273'),
#   'name': 'Embr Wave: A Thermostat For Your Body'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b4e5'),
#   'name': 'UGEARS: Self-propelled mechanical models'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b56a'),
#   'name': 'The Bolted Book Facsimile: An Exact Copy of Depero Futurista'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b628'), 'name': 'Xpand Lacing System'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b662'),
#   'name': 'Brawl in the Family: The Complete Collection'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b688'),
#   'name': "CamBuddy Pro: World's First All-In-One DSLR Smart Controller"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b861'),
#   'name': 'Carbon 6 Forged Carbon Fiber Glow Rings'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b8b4'),
#   'name': 'G-RO: Revolutionary Carry-on Luggage'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b8cd'),
#   'name': 'Jelly, The Smallest 4G Smartphone'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b94b'),
#   'name': 'Sprout: HiFi Stereo Amp that transforms the way you listen'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b9b1'),
#   'name': 'Polygons | The Flat 4-in-1 Measuring Spoon'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747b9ef'),
#   'name': 'The Worlds best TRAVEL PILLOW: 9 features packed in 1 pillow'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747bbed'),
#   'name': 'Petcube Bites + Petcube Play: Treat & Care for Pets Remotely'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747bc1d'),
#   'name': 'SCIENCE: Ruining Everything Since 1543 (an SMBC Collection)'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747be05'),
#   'name': "The Lomo'Instant Square Camera"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747be8d'),
#   'name': 'Maluna: Premium Coolers that Ice the Competition by 20%'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747bed5'),
#   'name': 'SELF Journal: Your Daily Structure for Success'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c220'),
#   'name': 'Arsenal, the intelligent camera assistant'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c329'),
#   'name': 'DreamScreen HD & 4K - Smart TV Backlighting for any HDMI TV!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c39c'),
#   'name': 'Numenera: A new roleplaying game from Monte Cook'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c439'),
#   'name': 'Equiso Smart TV - Make your dumb tv... smart.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c5cc'),
#   'name': 'Thimbleweed Park: A New Classic Point & Click Adventure!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c5d0'), 'name': 'Mordhau'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c62a'),
#   'name': 'anonabox : a Tor hardware router (Suspended)'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c700'),
#   'name': 'Chipolo - Bluetooth Item Finder for iPhone and Android'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c738'),
#   'name': 'Kickstarter Gold: Science Abridged'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c842'),
#   'name': 'Zombicide: Black Plague'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747c97a'), 'name': 'Save Movie Madness'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747ca5f'),
#   'name': 'jamstik+ The SmartGuitar'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747cb2d'), 'name': 'Blood and Plunder'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747cf52'),
#   'name': "Space Case 1 - The World's Most Advanced Smart Suitcase"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747cf56'),
#   'name': 'KNASA Chef Knife Inspired by NASA - Patented Technology'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d049'),
#   'name': 'Adaptive Saber Parts - Make your dream lightsaber a reality.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d0f8'),
#   'name': 'MagMod - Magnetic Speedlite Modifiers for Hot-Shoe Flashes'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d103'),
#   'name': "Let's Dub ARIA The ANIMATION for Blu-Ray"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d195'),
#   'name': "Purpleï¿½ Pillow: The World's First No-Pressure Head Bed"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d1f9'),
#   'name': 'GoSun Grill: A Breakthrough Solar Oven that Cooks at Night'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d242'),
#   'name': 'Build Entheon with Alex Grey & Allyson Grey'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d301'),
#   'name': 'Home Aquaponics Kit: Self-Cleaning Fish Tank That Grows Food'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d332'),
#   'name': 'SELFLY Camera: The smart, flying, phone case camera'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d33b'),
#   'name': 'HOT Watch:Complete Smart Watch w/Revolutionary Private Calls'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d365'),
#   'name': "The World's First Full HD 360ï¿½ Camera"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d502'),
#   'name': 'ATLAS 3D - The 3D Scanner You Print and Build Yourself!'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d68d'),
#   'name': 'Dragonï¿½s Lair: The Movie ( )'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d718'),
#   'name': 'Warpath - The Sci-fi Battle Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d7f9'),
#   'name': 'Bears Ears Education Center'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d83b'),
#   'name': 'Boss Monster: The Next Level'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d980'),
#   'name': 'Martians: A Story of Civilization'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747d9e0'),
#   'name': 'An Honest Liar: The Amazing Randi Story'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747dad3'),
#   'name': 'Petcube ï¿½ stay closer to your pet'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747db5b'),
#   'name': 'AllSteady-6Pro DSLR/Red 3-Axis Gimbal Stabilizer'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747dc75'),
#   'name': 'Fret Zeppelin - Play Guitar in 60 Seconds'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747dc9e'),
#   'name': 'BOOKNITURE- Furniture Hidden in a Book'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747dcf0'),
#   'name': 'PowerUp 3.0 - Smartphone Controlled Paper Airplane'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747de30'),
#   'name': 'Ube WiFi Connected Smart Light Dimmer'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747de88'),
#   'name': 'OSTRICH PILLOW GO ï¿½ Maximum comfort sleep for all necks'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747df2d'),
#   'name': 'Full-size reissue of the NYCTA Graphics Standards Manual.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747df7f'),
#   'name': 'The Gamers: Hands of Fate'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747dfa3'),
#   'name': 'HomeBiogas 2.0: Transforms Your Food Waste Into Clean Energy'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747dfad'), 'name': 'Font Awesome 5'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747dfbe'),
#   'name': 'Pen Type-A : A minimal pen'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747dfea'),
#   'name': 'Point: A softer take on home security.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e0b4'),
#   'name': 'The Aviary Cocktail Book'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e0e0'),
#   'name': 'HALLAM new york SMART JACKET 2.0 for TRAVEL, for OUTDOOR'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e119'),
#   'name': 'Time of Legends: Joan of Arc'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e141'),
#   'name': 'MORPHEUS delta; Fine Quality Resin 3D Printer at FDM price.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e14d'),
#   'name': 'Smart Herb Garden by Click & Grow'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e2f5'),
#   'name': 'ClickPack Pro | The Best Functional Anti-theft BackPack'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e30b'),
#   'name': 'Through the Breach: A Malifaux Roleplaying Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e3f9'),
#   'name': 'Pathfinder: Kingmaker'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e529'),
#   'name': "Noke: The World's First Bluetooth Padlock"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e7ff'),
#   'name': 'Two Guys SpaceVenture - by the creators of Space Quest'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e83d'),
#   'name': 'The Everyday Backpack, Tote, and Sling'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e93a'),
#   'name': 'The bFanï¿½: For a Cooler, more Restful nights sleep.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e9d7'),
#   'name': 'PrioVR: Suit up. Game on.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747e9e4'),
#   'name': 'Sidemen: Long Road To Glory - Narrated by Marc Maron'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747ea8d'),
#   'name': 'Customizable 3D Printed Tabletop Miniatures'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747eab7'),
#   'name': 'The Digital Bolex: The 1st Affordable Digital Cinema Camera'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747eb44'),
#   'name': "8-in-1 EVOLUTION BRA: The World's Most Advanced Bra"},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747eb85'),
#   'name': 'Mega Manï¿½ The Board Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747ee90'), 'name': 'Obduction'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747eeee'),
#   'name': 'Sprite: portable and rugged.  A totally different drone.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f116'),
#   'name': '1979 REVOLUTION: Black Friday'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f173'),
#   'name': 'TAKTIK: Premium Protection System for the iPhone'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f1dd'),
#   'name': 'Enchant your photography - unleash the magic Lydith 30/f3.5'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f23a'),
#   'name': 'Deathfire: Ruins of Nethermore RPG'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f2e2'), 'name': 'Torg Eternity'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f370'),
#   'name': 'Xia: Legends of a Drift System'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f44e'),
#   'name': 'The Tribal Collection | Wooden Polarized Shades'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f6cc'),
#   'name': 'ORII - Your Voice Powered Smart Ring'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f6de'),
#   'name': 'Time of EVE: The Movie on Blu-ray'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f840'),
#   'name': 'War Room: A Larry Harris Game'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f88b'),
#   'name': 'Republique by Camouflaj + Logan'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747f98f'),
#   'name': 'Hub+ for USB-C: Get your MacBook ports back.'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747fb2b'),
#   'name': 'The Field Skillet: Lighter, Smoother Cast Iron'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747fdec'),
#   'name': 'Handcrafted Dress Shoes Reinvented for the Modern Gentleman'},
#  {'_id': ObjectId('61af67a8f7a5cbe2d747feab'), 'name': 'Giant Unicorn Lamp'}]

# %% [markdown]
# ## Question 6

# %%
sport = collection.find({"name":{"$regrex":"Sport"}})
list(sport)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-140-0fc079fe9fe8> in <module>
#       1 sport = collection.find({"name":{"$regrex":"Sport"}})
# ----> 2 list(sport)
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1157         if self.__empty:
#    1158             raise StopIteration
# -> 1159         if len(self.__data) or self._refresh():
#    1160             return self.__data.popleft()
#    1161         else:
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1078                                   self.__allow_disk_use,
#    1079                                   self.__exhaust)
# -> 1080             self.__send_message(q)
#    1081         elif self.__id:  # Get More
#    1082             if self.__limit:
#
# ~\Anaconda3\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#     970         try:
#     971             response = client._run_operation(
# --> 972                 operation, self._unpack_response, address=self.__address)
#     973         except OperationFailure as exc:
#     974             if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1215         return self._retryable_read(
#    1216             _cmd, operation.read_preference, operation.session,
# -> 1217             address=address, retryable=isinstance(operation, message._Query))
#    1218
#    1219     def _retry_with_session(self, retryable, func, session, bulk):
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1311                         # not support retryable reads, raise the last error.
#    1312                         raise last_error
# -> 1313                     return func(session, server, sock_info, secondary_ok)
#    1314             except ServerSelectionTimeoutError:
#    1315                 if retrying:
#
# ~\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _cmd(session, server, sock_info, secondary_ok)
#    1211             return server.run_operation(
#    1212                 sock_info, operation, secondary_ok, self._event_listeners,
# -> 1213                 unpack_res)
#    1214
#    1215         return self._retryable_read(
#
# ~\Anaconda3\lib\site-packages\pymongo\server.py in run_operation(self, sock_info, operation, set_secondary_okay, listeners, unpack_res)
#     127                 first = docs[0]
#     128                 operation.client._process_response(first, operation.session)
# --> 129                 _check_command_response(first, sock_info.max_wire_version)
#     130         except Exception as exc:
#     131             if publish:
#
# ~\Anaconda3\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     168         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     169
# --> 170     raise OperationFailure(errmsg, code, response, max_wire_version)
#     171
#     172
#
# OperationFailure: unknown operator: $regrex, full error: {'ok': 0.0, 'errmsg': 'unknown operator: $regrex', 'code': 2, 'codeName': 'BadValue'}
